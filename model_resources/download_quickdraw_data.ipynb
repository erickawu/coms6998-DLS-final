# %%
from google.colab import drive
drive.mount('/content/drive')
root = "/content/drive/MyDrive/DLFinalProject/QuickDraw-pytorch"
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/DLFinalProject/QuickDraw-pytorch/
# !python DataUtils/prepare_data.py -c 100 -d 1 -show
# Out:
# /content/drive/MyDrive/DLFinalProject/QuickDraw-pytorch
# ...
